# %% [markdown]
# # 07. Portfolio Pre-processing

# %%
# Imports iniciais
import xml.etree.ElementTree as ET
import numpy as np
import pandas as pd

# Pacote para ignorar mensagem de warning
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the XML file
tree = ET.parse('C:/Users/mauri/OneDrive/Repositorios/AI-Cop_SLR/data/raw/portfolio-135.xml')
root = tree.getroot()

# Define a empty list to store the data
port_135_list = []

# Iterate over the <record> elements and extract the information
for record in root.findall('records/record'):
    
    # Extract data from each field
    database = record.find('database').text if record.find('database') is not None else None
    ref_type = record.find('ref-type').get('name') if record.find('ref-type') is not None else None
    authors = ", ".join([author.text for author in record.findall('contributors/authors/author')]) if record.findall('contributors/authors/author') is not None else None
    title = record.find('titles/title').text if record.find('titles/title') is not None else None
    secondary_title = record.find('titles/secondary-title').text if record.find('titles/secondary-title') is not None else None
    periodical = record.find('periodical/full-title').text if record.find('periodical/full-title') is not None else None
    pages = record.find('pages').text if record.find('pages') is not None else None
    volume = record.find('volume').text if record.find('volume') is not None else None
    issue = record.find('issue').text if record.find('issue') is not None else None
    keywords = ", ".join([keyword.text for keyword in record.findall('keywords/keyword')]) if record.findall('keywords/keyword') is not None else None
    year = record.find('dates/year').text if record.find('dates/year') is not None else None
    DOI = record.find('electronic-resource-num').text if record.find('electronic-resource-num') is not None else None
    pdf_url = record.find('urls/pdf-urls/url').text if record.find('urls/pdf-urls/url') is not None else None
    web_url = record.find('urls/web-urls/url').text if record.find('urls/web-urls/url') is not None else None
    abstract = record.find('abstract').text if record.find('abstract') is not None else None
    
    # Add the extracted data to the list
    port_135_list.append([database, ref_type, authors, title, secondary_title, periodical, pages, volume, issue, keywords, year, DOI, pdf_url, web_url, abstract])

# Create a DataFrame with the data
df = pd.DataFrame(port_135_list, columns=['database', 'ref-type', 'authors', 'title', 'secondary-title', 'periodical', 'pages', 'volume', 'issue', 'keywords', 'year', 'DOI', 'pdf_url', 'web_url', 'abstract'])

# Check the result
df.head(3)
# Out:
#             database         ref-type  \
# 0  PORTFOLIO-135.enl  Journal Article
# 1  PORTFOLIO-135.enl  Journal Article
# 2  PORTFOLIO-135.enl  Journal Article
#
#                                              authors  \
# 0  Beccali, Marco, Ciulla, Giuseppina, Lo Brano, ...
# 1                                       Giest, Sarah
# 2   Shah, Naimatullah, Irani, Zahir, Sharif, Amir M.
#
#                                                title  \
# 0  Artificial neural network decision support too...
# 1       Big data for policymaking: fad or fasttrack?
# 2  Big data in an HR context: Exploring organizat...
#
#                 secondary-title                    periodical      pages  \
# 0                        Energy                        Energy  1201-1218
# 1               Policy Sciences               Policy Sciences  367 - 382
# 2  Journal of Business Research  Journal of Business Research    366-378
#
#   volume issue                                           keywords  year  \
# 0    137  None  ANN, Decision support tool, Energy audit, Ener...  2017
# 1     50     3  Big data, Data readiness, Digital-era governan...  2017
# 2     70  None  Big data, Employee readiness, Extrinsic and in...  2017
#
#                              DOI  \
# 0   10.1016/j.energy.2017.05.200
# 1      10.1007/s11077-017-9293-1
# 2  10.1016/j.jbusres.2016.08.010
#
#                                              pdf_url  \
# 0  internal-pdf://2017 - Beccali et al. - Energy.pdf
# 1  internal-pdf://2017 - Giest - Policy Sciences.pdf
# 2  internal-pdf://2017 - Shah, Irani, Sharif - Jo...
#
#                                              web_url  \
# 0  https://linkinghub.elsevier.com/retrieve/pii/S...
# 1  https://www.scopus.com/inward/record.uri?eid=2...
# 2  https://linkinghub.elsevier.com/retrieve/pii/S...
#
#                                             abstract
# 0  The public buildings sector represents one of ...
# 1  The buzz surrounding big data has taken shape ...
# 2  This research highlights a contextual applicat...

# %%
types_list = df['ref-type'].value_counts()
print(types_list)
# Out:
# ref-type
# Journal Article    135
# Name: count, dtype: int64

# %%
df.value_counts(df['secondary-title'] == df['periodical'])
# Out:
# True    135
# Name: count, dtype: int64

# %%
# Como as colunas 'secondary-title' e 'periodical' são idênticas, vamos excluir uma e renomear a outra.
df.drop('periodical', axis=1, inplace=True)

# %%
df.rename(columns={'secondary-title':'journal'}, inplace=True)

# %%
print(df.columns)
# Out:
# Index(['database', 'ref-type', 'authors', 'title', 'journal', 'pages',
#        'volume', 'issue', 'keywords', 'year', 'DOI', 'pdf_url', 'web_url',
#        'abstract'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  database         ref-type        authors  \
# count                 135              135            135
# unique                  1                1            133
# top     PORTFOLIO-135.enl  Journal Article  Ingrams, Alex
# freq                  135              135              2
#
#                                                     title  \
# count                                                 135
# unique                                                135
# top     Artificial neural network decision support too...
# freq                                                    1
#
#                                  journal      pages volume issue keywords  \
# count                                135        116    126    98      135
# unique                                68        116     71    14      117
# top     Government Information Quarterly  1201-1218     39     1
# freq                                  23          1     10    25       18
#
#         year                           DOI  \
# count    135                           135
# unique     8                           135
# top     2022  10.1016/j.energy.2017.05.200
# freq      29                             1
#
#                                                   pdf_url  \
# count                                                 135
# unique                                                135
# top     internal-pdf://2017 - Beccali et al. - Energy.pdf
# freq                                                    1
#
#                                                   web_url  \
# count                                                 134
# unique                                                134
# top     https://linkinghub.elsevier.com/retrieve/pii/S...
# freq                                                    1
#
#                                                  abstract
# count                                                 134
# unique                                                134
# top     The public buildings sector represents one of ...
# freq                                                    1

# %%
# Converter para strings e remover os símbolos '[' e ']'
df['authors'] = df['authors'].astype(str).str.replace('[', '', regex=False).str.replace(']', '', regex=False)
df['keywords'] = df['keywords'].astype(str).str.replace('[', '', regex=False).str.replace(']', '', regex=False)

# Verificar o resultado
print(df[['authors', 'keywords']].head())
# Out:
#                                              authors  \
# 0  Beccali, Marco, Ciulla, Giuseppina, Lo Brano, ...
# 1                                       Giest, Sarah
# 2   Shah, Naimatullah, Irani, Zahir, Sharif, Amir M.
# 3                    Desouza, Kevin C., Jacob, Benoy
# 4  Klievink, Bram, Romijn, Bart-Jan, Cunningham, ...
#
#                                             keywords
# 0  ANN, Decision support tool, Energy audit, Ener...
# 1  Big data, Data readiness, Digital-era governan...
# 2  Big data, Employee readiness, Extrinsic and in...
# 3  big data, policy analysis, public management, ...
# 4  Assessment, Big data, Bold Readiness, E-govern...

# %%
def replace_alternate_commas(text):
    result = []
    comma_count = 0  # Contador para rastrear cada vírgula

    # Percorrer cada caractere da string
    for char in text:
        if char == ',':
            comma_count += 1
            # Substituir a vírgula por ponto e vírgula em contagens pares
            if comma_count % 2 == 0:
                result.append(';')
            else:
                result.append(char)
        else:
            result.append(char)

    # Retornar a string modificada
    return ''.join(result)

# Aplicar a função na coluna 'authors'
df['authors'] = df['authors'].apply(replace_alternate_commas)

# Verificar o resultado
print(df['authors'].head())
# Out:
# 0    Beccali, Marco; Ciulla, Giuseppina; Lo Brano, ...
# 1                                         Giest, Sarah
# 2     Shah, Naimatullah; Irani, Zahir; Sharif, Amir M.
# 3                      Desouza, Kevin C.; Jacob, Benoy
# 4    Klievink, Bram; Romijn, Bart-Jan; Cunningham, ...
# Name: authors, dtype: object

# %%
# Converter as colunas em listas
df['authors'] = df['authors'].str.split(';').apply(lambda x: [a.strip() for a in x])
df['keywords'] = df['keywords'].str.split(',').apply(lambda x: [k.strip() for k in x])

# Explodir as colunas sequencialmente
df_exploded = df.explode('authors').explode('keywords')

# Opcional: Resetar o índice
df_exploded.reset_index(drop=True, inplace=True)

# Visualizar o DataFrame final
print(df_exploded)
# Out:
#                database         ref-type          authors  \
# 0     PORTFOLIO-135.enl  Journal Article   Beccali, Marco
# 1     PORTFOLIO-135.enl  Journal Article   Beccali, Marco
# 2     PORTFOLIO-135.enl  Journal Article   Beccali, Marco
# 3     PORTFOLIO-135.enl  Journal Article   Beccali, Marco
# 4     PORTFOLIO-135.enl  Journal Article   Beccali, Marco
# ...                 ...              ...              ...
# 1716  PORTFOLIO-135.enl  Journal Article   Plewa, Carolin
# 1717  PORTFOLIO-135.enl  Journal Article  Reaiche, Carmen
# 1718  PORTFOLIO-135.enl  Journal Article  Reaiche, Carmen
# 1719  PORTFOLIO-135.enl  Journal Article  Reaiche, Carmen
# 1720  PORTFOLIO-135.enl  Journal Article  Reaiche, Carmen
#
#                                                   title  \
# 0     Artificial neural network decision support too...
# 1     Artificial neural network decision support too...
# 2     Artificial neural network decision support too...
# 3     Artificial neural network decision support too...
# 4     Artificial neural network decision support too...
# ...                                                 ...
# 1716  Virtual agents in the public service: examinin...
# 1717  Virtual agents in the public service: examinin...
# 1718  Virtual agents in the public service: examinin...
# 1719  Virtual agents in the public service: examinin...
# 1720  Virtual agents in the public service: examinin...
#
#                        journal      pages volume issue  \
# 0                       Energy  1201-1218    137  None
# 1                       Energy  1201-1218    137  None
# 2                       Energy  1201-1218    137  None
# 3                       Energy  1201-1218    137  None
# 4                       Energy  1201-1218    137  None
# ...                        ...        ...    ...   ...
# 1716  Public Management Review      73-88     26     1
# 1717  Public Management Review      73-88     26     1
# 1718  Public Management Review      73-88     26     1
# 1719  Public Management Review      73-88     26     1
# 1720  Public Management Review      73-88     26     1
#
#                       keywords  year                            DOI  \
# 0                          ANN  2017   10.1016/j.energy.2017.05.200
# 1        Decision support tool  2017   10.1016/j.energy.2017.05.200
# 2                 Energy audit  2017   10.1016/j.energy.2017.05.200
# 3            Energy efficiency  2017   10.1016/j.energy.2017.05.200
# 4     Non-residential building  2017   10.1016/j.energy.2017.05.200
# ...                        ...   ...                            ...
# 1716             virtual agent  2024  10.1080/14719037.2022.2044504
# 1717              e-government  2024  10.1080/14719037.2022.2044504
# 1718         value co-creation  2024  10.1080/14719037.2022.2044504
# 1719              value-in-use  2024  10.1080/14719037.2022.2044504
# 1720             virtual agent  2024  10.1080/14719037.2022.2044504
#
#                                                 pdf_url  \
# 0     internal-pdf://2017 - Beccali et al. - Energy.pdf
# 1     internal-pdf://2017 - Beccali et al. - Energy.pdf
# 2     internal-pdf://2017 - Beccali et al. - Energy.pdf
# 3     internal-pdf://2017 - Beccali et al. - Energy.pdf
# 4     internal-pdf://2017 - Beccali et al. - Energy.pdf
# ...                                                 ...
# 1716  internal-pdf://2024 - Scutella, Plewa, Reaiche...
# 1717  internal-pdf://2024 - Scutella, Plewa, Reaiche...
# 1718  internal-pdf://2024 - Scutella, Plewa, Reaiche...
# 1719  internal-pdf://2024 - Scutella, Plewa, Reaiche...
# 1720  internal-pdf://2024 - Scutella, Plewa, Reaiche...
#
#                                                 web_url  \
# 0     https://linkinghub.elsevier.com/retrieve/pii/S...
# 1     https://linkinghub.elsevier.com/retrieve/pii/S...
# 2     https://linkinghub.elsevier.com/retrieve/pii/S...
# 3     https://linkinghub.elsevier.com/retrieve/pii/S...
# 4     https://linkinghub.elsevier.com/retrieve/pii/S...
# ...                                                 ...
# 1716  https://www.tandfonline.com/doi/full/10.1080/1...
# 1717  https://www.tandfonline.com/doi/full/10.1080/1...
# 1718  https://www.tandfonline.com/doi/full/10.1080/1...
# 1719  https://www.tandfonline.com/doi/full/10.1080/1...
# 1720  https://www.tandfonline.com/doi/full/10.1080/1...
#
#                                                abstract
# 0     The public buildings sector represents one of ...
# 1     The public buildings sector represents one of ...
# 2     The public buildings sector represents one of ...
# 3     The public buildings sector represents one of ...
# 4     The public buildings sector represents one of ...
# ...                                                 ...
# 1716  The importance of today's public sector delive...
# 1717  The importance of today's public sector delive...
# 1718  The importance of today's public sector delive...
# 1719  The importance of today's public sector delive...
# 1720  The importance of today's public sector delive...
#
# [1721 rows x 14 columns]

# %%
df_exploded.to_excel('C:/Users/mauri/OneDrive/Repositorios/AI-Cop_SLR/data/processed/_11_portfolio-135-final.xlsx', index=False)

# %% [markdown]
# ---
